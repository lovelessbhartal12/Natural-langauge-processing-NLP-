# %% [markdown]
# <a href="https://colab.research.google.com/github/lovelessbhartal12/Natural-langauge-processing-NLP-/blob/main/text_preprocessing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
import pandas as pd

df = pd.read_csv(
    '/content/IMDB Dataset.csv',
    quoting=3,
    on_bad_lines='skip',
    encoding='utf-8'
)

# %%
df.shape
# Out:
# (3668, 2)

# %%
df = df.dropna(subset=['review'])

# %% [markdown]
# lower case converter

# %%
df['review'].iloc[550].lower()
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# /tmp/ipython-input-1242866809.py in <cell line: 0>()
# ----> 1 df['review'].iloc[550].lower()
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/indexing.py in __getitem__(self, key)
#    1189             maybe_callable = com.apply_if_callable(key, self.obj)
#    1190             maybe_callable = self._check_deprecated_callable_usage(key, maybe_callable)
# -> 1191             return self._getitem_axis(maybe_callable, axis=axis)
#    1192
#    1193     def _is_scalar_access(self, key: tuple):
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/indexing.py in _getitem_axis(self, key, axis)
#    1750
#    1751             # validate the location
# -> 1752             self._validate_integer(key, axis)
#    1753
#    1754             return self.obj._ixs(key, axis=axis)
#
# ...

# %%
df['review']=df['review'].str.lower()

# %% [markdown]
# Removing the HTML TAG

# %%
df['review'][30]

# %%
import re
def remove_tag(data):
  pattern=re.compile('<.*?>')
  return pattern.sub(r'',data)

# %%
df['review']=df['review'].apply(remove_tag)

# %%
df['review'][100]

# %%
import pandas as pd
import numpy as np

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# Removal of the URL

# %%
import re

def remove_url(data1):
    pattern = re.compile(r'https?://\S+|www\.\S+')
    return pattern.sub('', data1)

# %%
text='check out my notebook https://colab.research.google.com/drive/1BwYIBFF_Lqzm-DJVcdXuLDc8gZm1AaqO#scrollTo=w2aTsDhbJ44D'
text1='check out my youtube https://www.youtube.com/watch?v=6C0sLtw5ctc&list=PLKnIA16_RmvZo7fp5kkIth6nRTeQQsjfX&index=4 '
text2='my,email! "the perosn"is https://www.youtube.com/watch?v=6C0sLtw5ctc&list=PLKnIA16_RmvZo7fp5kkIth6nRTeQQsjfX&index=4'

# %%
remove_url(text1)

# %% [markdown]
# Removal of the punctuation

# %%
import string,time

# %%
exclude=string.punctuation

# %%
def remove_puncation(text):
  for char in exclude:
    text=text.replace(char,'')
  return text

# %%
remove_puncation(text2)

# %%
def remove_puncation1(text):
  return text.translate(str.maketrans('','', exclude))

# %%
remove_puncation1(text2)

# %% [markdown]
# Chatbot treatment

# %%
chat_words = {
    "IMHO": "in my humble opinion",
    "LOL": "laughing out loud",
    "OMG": "oh my god",
    "BTW": "by the way",
    "IDK": "I don't know",
    "PLZ": "please",
    "U": "you",
    "UR": "your",
    "BRB": "be right back",
    "THX": "thanks",
    "GG": "good game"
}

# %%
def chat_conversion(text):
  new_text=[]
  for w in text.split():
    if w.upper() in  chat_words:
      new_text.append(chat_words[w.upper()])
    else:
      new_text.append(w)
  return " ".join(new_text)

# %%
chat_conversion('IMHO HE IS THE BEST PLAER')

# %% [markdown]
# SPEELING CHECKING

# %%
from textblob import TextBlob

# %%
incorrect_text='ceertain condtion haas specific of my noteboook and my broother ntebook'
textblob=TextBlob(incorrect_text)
textblob.correct().string

# %% [markdown]
# Removing the stop word

# %%
import nltk
nltk.download('stopwords')

# %%
from nltk.corpus import stopwords

# %%
stopwords.words('english')

# %%
def remove_stopword(text):
  new_text=[]
  for word in text.split():
    if word in stopwords.words('english'):
      new_text.append('')
    else:
      new_text.append(word)
  x=new_text[:]
  new_text.clear()
  return ''.join(x)

# %%
remove_stopword('probably my name is a lovelesss bhartal')

# %% [markdown]
# Handling the emoji

# %%
# !pip install emoji

# %%
import emoji

# %%
def emoji_to_text(text):
    return emoji.demojize(text, delimiters=(" ", " "))

# %%
emoji_to_text("I love this movie 😍🔥")

# %% [markdown]
# Tokenization

# %% [markdown]
# 1) uisng the split function

# %%
sent='i am going to nepal for wathching the NPL'
sent.split()
# Out:
# ['i', 'am', 'going', 'to', 'nepal', 'for', 'wathching', 'the', 'NPL']

# %%
sent1='my name is loveless bahrtal. I am currently pursing the computer engineering at national. I am good'
sent1.split('.')
# Out:
# ['my name is loveless bahrtal',
#  ' I am currently pursing the computer engineering at national',
#  ' I am good']

# %% [markdown]
# 2)USING THE REGULAR EXPRESSION

# %%
import re
sent3='ohhh! this place is just wow.'
token=re.compile

# %% [markdown]
# 3) using NLTK

# %%
import nltk
nltk.download("punkt_tab")
# Out:
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt_tab.zip.
# True

# %%
import nltk
from nltk.tokenize import word_tokenize, sent_tokenize

# %%
data1='i am from nepal!'
word_tokenize(data1)
# Out:
# ['i', 'am', 'from', 'nepal', '!']

# %%
data2='i am currently purising a B.C.T in nepal! and i walk 10 km per day'
sent_tokenize(data2)
# Out:
# ['i am currently purising a B.C.T in nepal!', 'and i walk 10 km per day']

# %% [markdown]
# STEMMING

# %%
import nltk
from nltk.stem.porter import PorterStemmer

# %%
ps=PorterStemmer()
def stem_word(text):
  return " ".join([ps.stem(word) for word in text.split()])

# %%
data='walk walking walked walkes'

# %%
stem_word(data)
# Out:
# 'walk walk walk walk'
