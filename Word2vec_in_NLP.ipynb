# %% [markdown]
# <a href="https://colab.research.google.com/github/lovelessbhartal12/Natural-langauge-processing-NLP-/blob/main/Word2vec_in_NLP.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
# !pip install gensim
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 27.9/27.9 MB 36.3 MB/s eta 0:00:00
# ...

# %%
import gensim
from gensim.models import word2vec,keyedvectors

# %%
# !pip install wget
# Out:
# ...
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for wget: filename=wget-3.2-py3-none-any.whl size=9655 sha256=9ce8786488d0417829f257191050f76adb16a4994ce6a5e2e5352788d0cc7ec3
#   Stored in directory: /root/.cache/pip/wheels/01/46/3b/e29ffbe4ebe614ff224bad40fc6a5773a67a163251585a13a9
# Successfully built wget
# ...

# %%
import gensim.downloader as api

model = api.load("word2vec-google-news-300")
# Out:
# [==================================================] 100.0% 1662.8/1662.8MB downloaded

# %%
model['man']
# Out:
# array([-0.094386,  0.43007 , -0.17224 , -0.45529 ,  1.6447  ,  0.40335 ,
#        -0.37263 ,  0.25071 , -0.10588 ,  0.10778 , -0.10848 ,  0.15181 ,
#        -0.65396 ,  0.55054 ,  0.59591 , -0.46278 ,  0.11847 ,  0.64448 ,
#        -0.70948 ,  0.23947 , -0.82905 ,  1.272   ,  0.033021,  0.2935  ,
#         0.3911  , -2.8094  , -0.70745 ,  0.4106  ,  0.3894  , -0.2913  ,
#         2.6124  , -0.34576 , -0.16832 ,  0.25154 ,  0.31216 ,  0.31639 ,
#         0.12539 , -0.012646,  0.22297 , -0.56585 , -0.086264,  0.62549 ,
#        -0.0576  ,  0.29375 ,  0.66005 , -0.53115 , -0.48233 , -0.97925 ,
#         0.53135 , -0.11725 ], dtype=float32)

# %%
model['bottle'].shape
# Out:
# (50,)

# %%
model.most_similar('man')
# Out:
# [('woman', 0.8860337734222412),
#  ('boy', 0.8564431071281433),
#  ('another', 0.8452839851379395),
#  ('old', 0.8372183442115784),
#  ('one', 0.827606201171875),
#  ('who', 0.8244695663452148),
#  ('him', 0.8194693922996521),
#  ('turned', 0.8154467940330505),
#  ('whose', 0.811974048614502),
#  ('himself', 0.807725727558136)]

# %%
model.most_similar('love')
# Out:
# [('dream', 0.8429608941078186),
#  ('life', 0.8403438925743103),
#  ('dreams', 0.8398564457893372),
#  ('loves', 0.8361135125160217),
#  ('me', 0.8351817727088928),
#  ('my', 0.822745144367218),
#  ('mind', 0.8217629194259644),
#  ('loving', 0.8107607364654541),
#  ('wonder', 0.8073382377624512),
#  ('soul', 0.8014912605285645)]

# %%
model.most_similar('war')
# Out:
# [('occupation', 0.8530306220054626),
#  ('invasion', 0.8487673401832581),
#  ('wars', 0.8247286081314087),
#  ('conflict', 0.8187748193740845),
#  ('fighting', 0.8163182139396667),
#  ('military', 0.8145555853843689),
#  ('iraq', 0.7879492044448853),
#  ('forces', 0.785483181476593),
#  ('wartime', 0.7843406200408936),
#  ('army', 0.7817054390907288)]

# %%
model.similarity('man','women')
# Out:
# np.float32(0.5981384)

# %%
model.doesnt_match(['php','java','bottle'])
# Out:
# 'bottle'
